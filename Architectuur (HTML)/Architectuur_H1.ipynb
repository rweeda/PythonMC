# %% [markdown]
# TODO:
# - replace all images with: https://course.cs.ru.nl/pythonVO/Jupyter/
#
# - uitwerkingen
#
# - filmpje H 16 alleen crop
#
# - 1.9: versiebeheer: installatie handleiding git + , zie ook opdracht 1.15?
#
# - video versiebeheer te gebruiken HTML 1.10 https://youtu.be/YFlzmKv1j6M
#
# - video tabellen crop: https://youtu.be/Kx-BirVjy5U
#
# - headers tekst andere kleur dan opdrachten. Bv: header blauw en opdrachten Groen

# %% [markdown]
# # <span style="color:brown">Hoofdstuk 1: Website maken met HTML</span>
# <hr>
#
# # <span style="color:brown"><span style="color:brown">1.1 Kennismaken met HTML</span>
#
# <table><tr><td>
#
# ## <span style="color:brown">World Wide Web</span>
# Het World Wide Web is een van de belangrijkste internettoepassingen.  De 'taal' waarmee de inhoud van webpagina's wordt gemaakt heet <b>HTML</b> (HyperText Markup Language). HTML zelf is gewoon tekst met codes daarin. Browsers zoals Google Chrome, Edge, Firefox, Safari, enz. lezen deze codes en tonen de webpagina's vervolgens op het beeldscherm. Naast HTML maken we ook gebruik van <b>CSS</b> (Cascading Style Sheets). In CSS leggen we de opmaak (dus kleuren, lettertypes e.d.) van een website vast. Maar daar komen we later op terug.
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Opdracht 1.1: Kennis maken met HTML-codes</span>
# a) Wil je zien hoe HTML eruitziet bij een website die je kent? Ga dan naar die webpagina, klik met je rechtermuisknop en kies ‘Paginabron weergeven’ of ‘Bron weergeven’. De code die dan in een nieuw tabblad wordt geladen is (in de meeste gevallen) HTML.
#
# b) Bekijk het instructie filmpje met uitleg over <a href="https://youtu.be/KAvagArI0B8">H1.1 t/m H1.5</a>:
#
#
# [![Watch the video](https://img.youtube.com/vi/_Mp7Xw41l7o/hqdefault.jpg)](https://www.youtube.com/embed/_Mp7Xw41l7o)
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Browser</span>
# ‘Browsen’ of ‘surfen’ op het World Wide Web doe je via een webbrowser. Het apparaat waarop de webbrowser is geïnstalleerd moet verbonden zijn met het internet via een modem of router. Die modem is aangesloten op het netwerk van een provider. De provider zorgt ervoor dat je van over heel de wereld websites (HTML-pagina’s dus) kunt binnenhalen.
#
# <img src="img/1.1_worldWideWeb.jpg" width="300" height="150" alt="World Wide Web">
#
# De HTML-pagina’s staan op servers. Dit zijn computers die speciaal zijn gemaakt zodat andere computers er makkelijk informatie vandaan kunnen halen. Dit gaat via het internet.
#
#
# Bekijk de volgende filmpje over HTML en het internet (7 minuten):
#
# [![Watch the video](https://img.youtube.com/vi/kBXQZMmiA4s/hqdefault.jpg)](https://www.youtube.com/embed/kBXQZMmiA4s)
#
# </td></tr></table>

# %% [markdown]
# <hr>
#
# # <span style="color:brown">1.2: HTML tags, head en body</span>
#
#
# <table><tr><td>
#
# Om een webpagina te maken moet je je houden aan een aantal regels. Met HTML wordt de structuur van een webpagina beschreven.
#  </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Tags en elementen</span>
# In de HTML-code wordt aangegeven, welke kopteksten, alinea's, klikbare links en afbeeldingen er zijn. Voor elk element in een geef je met tags (labels) aan wat het is. Bijvoorbeeld, de titel van je pagina, wat je bovenin de browser ziet geef je zo aan:
#
# ```<title>Mijn titel</title>```
#
# Zoals je kunt zien bestaat dit element uit drie onderdelen:
#
# - Een begintag, namelijk ```<title>```;
#
# - Inhoud, namelijk "Mijn titel";
#
# - Een eindtag, namelijk ```</title>```.
#
#
#
# Tags staan altijd tussen <code><</code> en <code>></code>. De meeste elementen hebben een begin- en eindtag.
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Structuur van een webpagina</span>
# Hieronder zie je een voorbeeld van HTML-code, met daaronder een uitleg over de codes.<br>
# <img src="img/1.3_WebPageStructure.png" width="400"  alt="Structuur van een webpagina" >
#
#
# Iedere webpagina begint met ```<html>``` en eindigt met ```</html>```.
# Binnen de HTML-tags heb je twee delen, namelijk 'head' en 'body':
#
# 1. <b>head</b>:
# Informatie over de website die je niet op de pagina zelf ziet, maar door de browser gebruikt wordt om het pagina te laten zien. Bijvoorbeeld:
#
# - Titel: Welk tekst getoond moet worden in de webbrowserbalk of op het titelblad. Bijvoorbeeld:<br>
# ```<title>Titel in de webbrowserbalk</title>```
#
# - Taal: Hiermee kan een zoekmachine zoals Google, taal specifieke resultaten geven. Of een browser kan een pagina vertalen als bekend is in welke taal de pagina is geschreven. Ook wordt het gebruikt door schermlezers (zoals Claroread) om een juiste uitspraak te geven. In dit voorbeeld "nl" voor Nederlands:<br>
# ```<html lang="nl">```
#
# - Karakterset: Unicode of Ascii. Om alle karakters wereldwijd te kunnnen tonen gebruik je UTF-8 dat voor UNICODE staat:<br>
# ```<meta charset="utf-8">```
#
# 2. <b>body</b>:
# De werkelijke inhoud van de pagina, dus wat je op het scherm ziet zoals een plaatje of een stuk tekst zoals in dit voorbeeld:<br>
#
# <div class="alert " markdown="1">
#
# ```
# <body>
#      Inhoud van mijn webpagina.
# </body>
# ```
# </div>
#
# </td></tr></table>

# %% [markdown]
# <hr>
#
# # <span style="color:brown">1.3: Programmeeromgeving VSC</span>
#
# <table><tr><td>
#
# Je gaat je eigen HTML-code schrijven, in Visual Studio Code (CSV). Om het resultaat van je code te zien moet je deze in een browser openen. Vanuit VSC gaat dat het makkelijkst door de <b>HTML Preview</b> extensie te downloaden.
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Opdracht 1.2: HTML extensie downloaden in Visual Studio Code (VSC)</span>
#
#  In deze opdracht ga je de HTML extensie downloaden. Volg daarvoor de volgende stappen:
#
# a) Klik links op de extensie-icoon:
# <p><img src="img/VSC_extension_icoon.png" alt="VSC extensie icoon" width="50"></p>
#
# b) Typ 'HTML preview' in de zoekbalk bovenin:
# <p><img src="img/VSC_extension_HTMLpreview.png" alt="VSC extensie icoon" width="300"></p>
#
# c) Kies dan voor een van de "HTML Preview"-extensies en druk op "Install".
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Opdracht 1.3: HTML-bestand bekijken</span>
#
# Elke website heeft een <i>index.html</i>, dit is de hoofdpagina. Wij bekijken nu hoe zo'n HTML-bestand eruit ziet.
#
# a) Open het voorbeeld <i>index.html</i> voor deze opdracht: <a href="Uitwerkingen/1_opdracht/index.html">index.html</a>.
# Als het goed is staat de volgende code in dat bestand:<br>
#
# <div class="alert"  markdown="1">
#
# ```
# <html>
#
#   <head>
#     <meta charset="utf-8">
#     <title>Mijn titel</title>
#   </head>
#
#   <body>
#     <p>Hier staat de inhoud van de pagina.</p>
#   </body>
#
# </html>
# ```
# </div>
#
#
#
# b) Om de code uit te voeren klik je met je rechtermuisknop op het '<i>index.html</i>' bestand en kies '<i>Show in Browser</i>'.
#
# c) De browser (bv. Chrome, Edge, Safari) opent de website.
#
# d) Als het goed is zie je in de browser de tekst verschijnen dat in de HTML-code tussen `<body>` en `</body>` staat, in dit geval: '<i>Hier staat de inhoud van de pagina.</i>'
#
# e) Zet de twee schermen naast elkaar zodat je ze makkelijk kunt vergelijken. Tip: Pak de browser en sleep die naar de rechterkant van je beeldscherm, of gebruik WINDOWS+pijltje. Als het goed is krijg je zo'n opstelling:<br>
#
#
# <img src="img/Opdracht1_3f.png" width="600" alt="World Wide Web">
#
#
#
# f) Vind waar de tekst '<i>Mijn titel</i>' in de HTML-code staat. Waar zie je deze tekst op de website terug?
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Opdracht 1.4: HTML-bestand aanpassen</span>
#
# a) Pas de tekst in de body van <i>index.html</i> aan en sla de wijziging op (tip: <b>CTRL</b> + <b>S</b>).
#
# b) Test je aanpassing door op de browser te verversen. Dit kan met <b>F5</b>, of door op het volgende icoontje te klikken:
#
# <img src="img/1.3_refreshBrowser.png" width="50" height="50" alt="Icoon ververs browser">
#
#
# Is het gelukt om de tekst op de website aan te passen?
#
# </td></tr></table>

# %% [markdown]
# <hr>
#
# # <span style="color:brown">1.4: Code structureren met inspringen</span>
#
# <table><tr><td>
# Door je code te structureren voorkom je dat je fouten maakt. Dit doe je door <i>in te springen</i>, zodat dingen die bij elkaar horen ook bij elkaar staan.
#
# Goed ingesprongen:<br>
# <img src="img/1.4_code_inspringen_goed.png" alt="Goed ingesprongen code" border="1">
#
# Niet goed ingesprongen:<br>
# <img src="img/1.4_code_inspringen_NietGoed.png" width="400" alt="Niet goed ingesprongen code" border="1">
#
#
# Inspringen doe je zo:
#
#
# - Begin- en eindtags staan steeds recht onder elkaar staan. Alleen wanneer de begin- en eindtag op één regel kunnen staan hoeft dat niet (al mag het wel).
#
# - Alles wat tussen een begin- en een eindtag staat wordt ingesprongen. Inspringen doe je met <b>TAB</b>. Je kunt ook meerdere regels selecteren en in een keer inspringen. Inspringen <i>ongedaan maken</i> doe je met <b>SHIFT+TAB</b>.
#
# - Als je met de cursor een tag te dubbelklikken (bv. ```<body>```) zie je ook de bijbehorende begin- of eind tag oplichten. Zo kun je ook heel snel zien welke tag bij welke hoort.
#
# </td></tr></table>

# %% [markdown]
# <hr>
#
# # <span style="color:brown">1.5: Koppen en alinea's</span>
#
# <table><tr><td>
#
#
# Bekijk hier een kort filmpje met uitleg over koppen (`<h1>`), subkoppen (`<h2>`, `<h3>`, ...) en alinea's (`<p>`):
#
#
# [![Watch the video](https://img.youtube.com/vi/O3jaUwLKrGQ/hqdefault.jpg)](https://www.youtube.com/embed/O3jaUwLKrGQ)
#
#
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Paragraaf alinea's</span>
# Een alinea tekst zet je tussen paragraaf-tags `<p>` ... `</p>`, bijvoorbeeld:<br>
# - `<p>Dit is een paragraaf</p>`
# </td></tr></table>

# %% [markdown]
#  <table><tr><td>
#
# ## <span style="color:brown">Koppen</span>
# Een kopje boven alinea geef je aan met `<h1>` … `</h1>`, bijvoorbeeld::<br>
# - ```<h1>Dit is een grote kop</h1>```
#
# De grootste kop heet h1.
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Subkoppen</span>
#
# Voor subkoppen gebruik je `<h2>` … `</h2>` of, nog kleiner met `<h3> … </h3>`. Bijvoorbeeld: <br>
# - `<h2>Dit is een subkop</h2>`<br>
#         - `<h3>Dit is nog een kleinere subkop</h3>`
#
# Webbrowsers passen dan automatisch de tekst grootte aan en maken de tekst dikgedrukt.
#
#
# <table><tr bgcolor="#FEF9E7"><td>
#   <b>Let op:</b> het getalletje geeft niet aan hoeveel koppen je hebt, maar hoe groot de koptekst getoond wordt. In het voorbeeld hieronder zie je dat er een hoofdkop is (h1) en twee subkoppen die even groot zijn (2 koppen van h2).
# </td></tr></table>
#
# Hier is een voorbeeld van HTML-code (links) en zoals het in de browser eruit ziet (rechts): <br>
#
#
# <table><tr bgcolor="#F5CBA7" align="left"><th>HTML-code:</th><th>In de browser:</th></tr>
# <tr bgcolor="#FEF9E7"><td>
# <div class="alert" markdown="1">
#
# ```
# <html>
#         <head>
#                 <meta charset="utf-8">
#                 <title>Mijn titel</title>
#         </head>
#
#         <body>
#             <h1>Dit is kop h1</h1>
#                 <p>Tekst zet je in een paragraaf, binnen een p-tag.</p>
#
#
#               <h2>Dit is subkop h2</h2>
#                 <p>Met wat tekst</p>
#
#               <h2>Dit is een tweede subkop h2</h2>
#                  <p>Ook hier zet je tekst in een paragraaf.</p>
#         </body>
# </html>
# ```
# </div>
# </td><td>
# <img src="img/1.5_uitvoer.png"  alt="HTML-code met kopjes"  width="300" border="1">
#
# </td></tr></table>
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Opdracht 1.5: Koppen, subkoppen en alinea's</span>
#
# We voegen wat tekst toe aan je pagina, bestaande uit 2 hoofdkoppen, 2 subkoppen en 3 paragraven:
#
#
# <img src="img/Opdracht1_5.png" width="600" border="1" alt="HTML-code met kopjes">
#
#
#
# We gebruiken de volgende tekst (links) en gaan deze met koppen vormgeven zoals je in de afbeelding rechts:
#
# <table>
# <tr bgcolor="#F5CBA7" align="left"><th width="50%">Tekst:</th><th>In de browser:</th><tr>
# <tr bgcolor="#FEF9E7"><td>
# Welkom
#
# Welkom op mijn receptenpagina. De tips komen van kookidee.nl.
#
# Kooptips
#
# Oventemperatuur
#
# Er zijn verschillende soorten ovens. Heb je een elektrische oven dan moet je ongeveer 10% bij de temperatuur optellen.
#
#
# Afmeten
#
# In veel van recepten meet je ingrediënten af met theelepels (tl.) of eetlepels (el.). Het handigst is om een setje maatlepels aan te schaffen.
# </td>
# <td>
# <img src="img/Opdracht1_5_uitvoer.png" width="500" border="1" alt="Uitvoer van opdracht 1.5">
# </td><tr>
# </table>
#
# a) Kopieër de tekst in <a href="Uitwerkingen/1_opdracht/1.5_opdracht_tekst.txt">dit bestand</a> en plak dat in de body van je pagina, dus tussen `<body>` en `</body>`.
#
# b) Geef aan dat <i>Welkom</i> en <i>Kooptips</i> twee grote koppen zijn met `<h1>` en `</h1>`.
#
# c) Sla je werk op (met <b>CTRL</b>+<b>S</b>). Bekijk daarna het resultaat in de browser om je werk te testen.
#
# d) Geef aan dat <i>Overtemperatuur</i> en <i>Afmeten</i> twee subkoppen zijn met `<h2>` en `</h2>`.
# Zorg ervoor dat je code netjes ingesprongen is. Gebruik de <b>TAB</b>-toets om ervoor te zorgen dat de `<h2>` netjes uitgelijnd staat, namelijk rechts van de `<h1>`. Bekijk eventueel de uitwerkingen.
#
# e) Sla je werk op (met <b>CTRL</b>+<b>S</b>) en bekijk het in de browser om je werk te testen.
#
# f) Zet de tekst onder elk (sub)kop tussen `<p>` en `</p>`. Houd je code netjes ingesprongen!
#
# g) Sla je werk op en bekijk het in de browser om je werk te testen.
#
# </td></tr></table>

# %% [markdown]
# <hr>
#
# # <span style="color:brown">1.6: Basis tekstopmaak</span>
#
# <table><tr><td>
#
# ## <span style="color:brown">Vetgedrukt, cursief, onderstreept </span>
# Er zijn elementen die je voor de opmaak van de tekst kunt gebruiken. De mogelijkheden van HTML-elementen voor de opmaak zijn vrij beperkt. De ‘echte’ opmaak van je website, zoals kleuren, gebeurt met CSS-code. Dit wordt later uitgelegd in hoofdstuk 3 (Website maken: CSS).
#
# <img src="img/1.6_tekstopmaak_uitlegtabel.png" border="1" alt="Uitleg basis tekstopmaak" width="600">
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Nieuwe regel</span>
#
# Met `<br>` kun je aangeven dat je met een nieuwe regel wil beginnen.
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Horizontale regel</span>
#
# Met `<hr>` trek je een horizontaal lijn.
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Opdracht 1.6. Tekstopmaak </span>
# Je doel is om aan je bestaande code opmaak toe te voegen, zoals hieronder:
#
# <img src="img/Opdracht1_6.png" border="1" alt="Uitvoer Opdracht 1.6">
#
#
#
# a) In het eerste alinea, laat de tweede zin op een nieuwe regel beginnen. Gebruik hiervoor `<br>`.
#
# b) Sla je werk op (<b>CTRL</b>+<b>S</b>) en bekijk het resultaat in de browser.
#
# c) Plaats een horizontale regel tussen de Welkom en Kooptips onderdelen. Gebruik hiervoor `<hr>`.
#
# d) Sla je werk op en bekijk het resultaat in de browser.
#
# e) Maak de '<i>10%</i>' vetgedrukt.
#
# f) Sla je werk op en bekijk het resultaat in de browser.
#
# g) Maak '<i>tl</i>' en '<i>el</i>' schuingedrukt.
#
# h) Sla je werk op en bekijk het resultaat in de browser.
#
#
# </td></tr></table>

# %% [markdown]
# <hr>
#
# # <span style="color:brown">1.7: Commentaar in je code</span>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Testen</span>
# Het is een goede gewoonte om na elke wijziging je code te Runnen en te testen. Een tikfoutje of een `>` of `/` weggelaten is namelijk zo gebeurt. Als je regelmatig je code test kun je snel achterhalen waar de fout zit.
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown"> Commentaar </span>
#
#
# Het is handig om voor jezelf aantekeningen te maken in je code. Wil je deze niet in de webpagina tonen, dan kun je gebruik maken van commentaartekens: `<!--` en `-->` <br>
# Bijvoorbeeld:<br>
#         `<!-- commentaar: Dit verschijnt niet op je webpagina. Let op begin en eind tekens. -->`
#
#
#
# <table>
# <tr bgcolor="#F5CBA7"><th width="50%">HTML-code:</th><th width="20%">In de browser:</th><tr>
# <tr bgcolor="#FEF9E7" valign="top"><td>
#
# ```
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>Mijn titel</title>
#   </head>
#
#   <body>
#     <h1>Dit is kop h1</h1>
#     <!-- commentaar: Verschijnt niet op webpagina -->
#       <p>Tekst zet je in een paragraaf, binnen een p-tag.</p>
#
#   </body>
# </html>
# ```
#
# </td><td>
#
# <img src="img/1.7_commentaar.png" border="1" alt="Commentaar is niet zichtbaar in de browser">
# </td>
# </tr>
# <table>
#
# Als je in je code een fout hebt gemaakt, en niet weet waar dat is, dan kan je delen van je code in commentaar zetten om er zo achter te komen waar het probleem zit.
#
# </td></tr><table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Opdracht 1.7: Commentaar</span>
#
# a) Zoek de `<br>` in je <i>index.html</i>. Geef in commentaar aan wat `<br>` doet (dus, wat gebeurt er in de browser als je `<br>` gebruikt)
#
# b) Sla <i>index.html</i> op en bekijk het resultaat in de browser. Controleer dat je commentaar inderdaad niet op je webpagina verschijnt.
#
# </td></tr></table>

# %% [markdown]
# <hr>
#
# # <span style="color:brown">1.8: Handige toetscombinaties</span>
#
# <table><tr bgcolor="#FEF9E7"><td>
#
#
# - CTRL+S: opslaan
# - F5: browser verversen
# - CTRL+X: knippen
# - CTRL+C: kopieren
# - CTRL+V: plakken
# - CTRL+Z: ongedaan maken
# - TAB: inspringen
# - SHIFT+TAB: inspringen ongedaan maken
# - WINDOWS+RECHTS: open 2 vensters naast elkaar
# - WINDOWS+SHIFT+S: maak een screenshot (foto van je scherm maken)
#
# </td></tr></table>

# %% [markdown]
# <hr>
#
# # <span id="H1.9" style="color:brown">1.9 Versiebeheer</span>
#
# <table><tr><td>
#
# Met versiebeheer kun je eenvoudig naar een oude (werkende) versie van je code. Om overzicht te houden geef je met een 'commit' met paar woorden de status van je werk aan. Zo weet je later om welke versie het gaat.
#
# Let op: Het is een goede gewoonte om alléén met werkende code een commit te doen.
#
# Bekijk hier een filmpje met uitleg over versiebeheer:
#
# TODO FILMPJE: https://youtu.be/YFlzmKv1j6M
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Opdracht 1.8: Versiebeheer instellen en gebruiken</span>
#
#
#
# a) Bekijk eerst het uilegfilmpje hierboven.
#
#
# EXTENSIE
#
# COMMIT
#
# MAAK EEN AANPASSING IN JE HTML EN SLA OP
#
# NIEUWE COMMIT
#
#
# Wil je ooit teruggaan naar een oude versie, dan kan dat met ...
# </td></tr></table>

# %% [markdown]
# <hr>
#
# # <span style="color:brown">1.10: Links</span>
#
# <table><tr><td>
#
# ## <span style="color:brown">Links naar andere pagina's, andere websites of bestanden</span>
#
# Met een hyperlink leg je een koppeling naar een andere webpagina maken. Klik je op een link, dan spring je naar de andere pagina.
#
# Er zijn verschillende soorten links:
#
# - Externe link: naar een andere website;
#
# - Interne link: naar een ander pagina binnen dezelfde website;
#
# - Link naar een bestand: link naar een eigen bestand dat de gebruiker kan downloaden.
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Externe link</span>
# Een link naar een andere website maak je zo:<br>
# ```<a href="https://montessoricollege.nl/"> Montessoricollege Nijmegen</a>```
#
# In je browser ziet dat er zo uit:<br>
# <a href="https://montessoricollege.nl/"> Montessoricollege Nijmegen</a><br>
#
# Als je in de pagina op de link Montessoricollege Nijmegen klikt opent de pagina op de site: https://montessoricollege.nl/
#
# Om een nieuwe venster te openen geef je 'target=_blank' in de tag mee:<br>
# ```<a href="https://montessoricollege.nl/" target=_blank> Montessoricollege Nijmegen </a>```
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Opdracht 1.9: Externe link </span>
#
#
# a) Open je <a href="Uitwerkingen/1_opdracht/index.html">index.html</a>.
#
# b) Maak van de tekst 'kookidee.nl' in het eerste alinea een link naar https://kookidee.nl/
#
# c) Sla op en test je link in de browser.
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Interne link</span>
#
#
# Meeste websites bestaan uit meerdere pagina's. Vaak wil je van de een naar de ander doorverwijzen. Om dan van de ene pagina naar de andere te kunnen springen gebruik je een <i>interne link</i> <br>
#
#
# &ensp;&ensp;<img src="img/1.9_interneLink.png" border="1" alt="Interne link: Link binnen dezelfde site" width="300">
#
# De code van een internet link ziet er zo uit:<br>
# ```<a href="pagina2.html">Link naar pagina2</a>```
#
#
# In de browser ziet dat er zo uit:<br>
# <a href="pagina2.html">Link naar pagina2</a><br>
#
#
# Als je op de link klikt wordt het bestand <i>pagina2.html</i> in de browser geopend.
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Opdracht 1.10: Interne link</span>
#
# Om een interne link te maken (dus van een pagina op je site naar een andere pagina op dezelfde site) moet je eerst een tweede pagina hebben, daarna kan je van de ene naar de andere linken.
#
# a) Maak een tweede pagina aan met de naam '<i>appeltaart.html</i>':
#
# - Klik in het menu bovenin op 'File' en dan 'New File':<br>
# &ensp;&ensp;<img src="img/VSC_newFile.png" border="1" width="350" alt="Nieuwe bestand maken in VSC">
#
# - Typ in het balk bovenaan '<i>appeltaart.html</i>' en sla deze op in hetzelfde map als je <i>index.html</i>, dus in "Uitwerkingen/1_opdracht".
#
#
# - Kopieër de code in <a href="Uitwerkingen/1_opdracht/appeltaart.txt">dit bestand</a> naar jouw '<i>appeltaart.html</i>'.
#
# b) Maak in je <i>index.html</i> (jouw hoofdpagina) een link naar je appeltaart pagina met:<br>
# `<a href="appeltaart.html">Mijn appeltaart pagina</a>`
#
# c) Sla je werk op en test of je link naar je appeltaart pagina werkt.
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Link naar een bestand maken</span>
#
# Je kunt ook een link maken naar een bestand die de gebruiker dan kan downloaden, bijvoorbeeld een PDF of Word bestand. Je moet dan aangeven waar het bestand opgeslagen staat.
#
# Voorbeeld: Stel dat je een pdf-bestand hebt met de naam '<i>bestandje.pdf</i>' die staat opgeslagen in dezelfde map als je html code. Om die op jouw website downloadbaar te maken zet je de volgende code op je pagina:<br>
#
# ```<a href="bestandje.pdf">Download de PDF bestand hier</a>```
#
# </td></tr></table>

# %% [markdown]
# <hr>
#
# # <span style="color:brown">1.11: Afbeeldingen</span>
#
# <table><tr><td>
#
# ## <span style="color:brown">Afbeelding invoegen</span>
#
# Om een afbeelding op je site te tonen moet je aangeven hoe die heet en waar die staat.
#
# Er zijn verschillende typen afbeeldingen, gebruik de juiste extensie, zoals .jpg, .gif en .png.
#
#
# <b>Voorbeeld 1:</b>
#
# Bestandsnaam van afbeelding: <i>appels.jpg</i>
#
# Als <i>appels.jpg</i> in de dezelfde map staat als je HTML-code verwijs je er zo naar:<br>
#
# ```<img src="appels.jpg">```
#
#
# <b>Voorbeeld 2:</b>
#
# Bestandsnaam van afbeelding: <i>appels.png</i>
#
# Als <i>appels.png</i> in een submapje 'img' staat verwijs je er zo naar:
#
# ```<img src="img/appels.png">```
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Opdracht 1.11: Afbeelding toevoegen</span>
#
# a) Zoek op het internet een plaatje van een appeltaart.
#
# b) Klik met je rechtermuisknop op 'Afbeelding opslaan als...':
#
#
# &ensp;&ensp;<img src="img/1.11_afbeeldingOpslaanAls.png" border="1" alt="Afbeelding opslaan als" width="250">
#
# c) Geef je plaatje een zinvolle naam, zoals bijvoorbeeld 'foto_appeltaart'. Let er op dat je geen spaties gebruikt.
#
#
# d) Sla de foto op in hetzelfde map als waar je <i>index.html</i> staat, dus in '<i>Uitwerkingen/1_opdracht</i>'.
#
#
# e) Voeg het plaatje toe aan je appeltaart.html pagina, onder het kopje foto. Let er op dat je de juiste extensie gebruikt, dus .jpg of .png.
#
#
# f) Sla je werk op en bekijk het resultaat in de browser. Klik naar je appeltaart pagina om te controleren of het plaatje verschijnt.
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Afbeelding klikbaar maken</span>
#
# Je kunt een afbeelding klikbaar maken. Als je op de site op de afbeelding klikt, ga je naar een bepaalde site.
#
# <b>Voorbeeld:</b>
#
# Bestandsnaam van afbeelding:  <i>appels.jpg </i>
#
# Link waar je heengaat als je daarop klikt: www.montiplaza.nl
#
# ```<a href="http://www.montiplaza.nl"> <img src="appels.jpg"> </a>```
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Opdracht 1.12: Afbeelding klikbaar maken</span>
#
# a) Zorg er voor dat als je op de afbeelding klikt, dat je naar een andere website gaat, bijvoorbeeld naar de site waar de afbeelding vandaan komt.
#
# b) Test je aanpassing.
#
# c) Als alles werkt is dit een mooi moment voor versiebeheer. Maak een commit:
#
# - Klik op het versiebeheer icoon:<br>
# &ensp;&ensp;<img src="img/VSC_versiebeheerIcoon.png" border="1" alt="Versiebeheer icoon in VSC">
#
#
# - Geef de commit een zinvolle naam:<br>
# &ensp;&ensp;<img src="img/VSC_commitLog.png" border="1" alt="Commit in VSC" width="200">
#
#
#
# - Upload je wijzigingen met 'Sync Changes': <br>
# &ensp;&ensp;<img src="img/VSC_syncChanges.png" border="1" alt="Sync commit in VSC">
#
#
#
# </td></tr></table>

# %% [markdown]
# <hr>
#
# # <span style="color:brown">1.12: Lijsten</span>
#
# <table><tr><td>
#
# Je kunt twee soorten lijsten maken:
#
# - `<ul>`: een ongeordende lijst (met opsommingstekens ervoor);
#
# - `<ol>`: een geordende lijst (met nummers ervoor).
#
#
# Om iets aan de lijst toe te voegen, gebruik je het `<li>`-element ('li' staat voor ‘list item').
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Ongeordende lijst</span>
#
# De code voor een <i>ongeordende lijst</i> (unordered list) met opsomminstekens ervoor ziet er zo uit:
#
#
#
#
# <table><tr bgcolor="#F5CBA7" align="left"><th>HTML-code:</th><th>In de browser:</th></tr>
# <tr bgcolor="#FEF9E7" valign="top"><td>
#
#
# ```
# <ul>
#     <li>Lijst item</li>
#     <li>Nog een lijst item</li>
#     <li>Enz.</li>
# </ul>
# ```
# </td>
# <td><img src="img/1.11_LijstenVoorbeeld_ongeordend.png" alt="Ongeordende lijst"></td>
# </tr>
# </table>
#
#
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ## <span style="color:brown">Geordende lijst</span>
#
# De code voor een <i>geordende lijst</i> (ordered list) met nummers ervoor ziet er zo uit:
#
#
# <table><tr bgcolor="#F5CBA7" align="left"><th>HTML-code:</th><th>In de browser:</th></tr>
# <tr bgcolor="#FEF9E7" valign="top"><td>
#
# ```
# <ol>
#         <li>Lijst item 1</li>
#         <li>Lijst item 2</li>
#         <li>Lijst item 3</li>
# </ol>
# ```
# </td>
# <td><img src="img/1.11_LijstenVoorbeeld_ordered.png" alt="Geordende lijst"></td>
# </tr>
# </table>
#
#
#
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Opdracht 1.15: Lijsten</span>
#
# Voeg twee lijsten toe aan je appeltaart pagina.
#
# a) Maak een ongeordende lijst met de ingrediënten die in <a href="Uitwerkingen/1_opdracht/1.15_opdracht_ingredienten.txt">dit bestand</a> staan. Gebruik hiervoor `<ul>`.
#
# Het resultaat zou er zo uit moeten zien:<br>
# &ensp;&ensp;<img src="img/Opdracht1_15_ongeoordendeLijst.png" border="1" alt="Ongeordende lijst">
#
#
# b) Maak een geordende lijst met de bereidingswijze in <a href="Uitwerkingen/1_opdracht/1.15_opdracht_bereidingswijze.txt">dit bestand</a>. Gebruik hiervoor `<ol>`. Je moet dus <i>niet</i> zelf getalling intikken!
#
#
# Het resultaat zou er zo uit moeten zien:<br>
# &ensp;&ensp;<img src="img/Opdracht1_15_geoordendeLijst.png" border="1" alt="Geordende lijst">

# %% [markdown]
# <hr>
#
# # <span style="color:brown">1.13: Tabellen</span>
#
# <table><tr><td>
# Bekijk hier een kort instructiefilmpje (1min 44s) over tabellen:
#
#
# [![Watch the video](https://img.youtube.com/vi/JDTzdHFLO_A/hqdefault.jpg)](https://www.youtube.com/embed/JDTzdHFLO_A)
#
#
# Werken met tabellen in HTML doe je met de elementen `<table>`, `<tr>` en `<td>`. Bekijk eerst het onderstaande plaatje om te begrijpen wat er wordt bedoeld met kolom, rij en cel:<br>
# &ensp;&ensp;<img src="img/1.13_tabelUitleg.png" border="1" alt="Uitleg structuur van tabel">
#
# Een tabel maken gaat in drie stappen:
#
# - Begin met een table-element: `<table>`.
#
#
# - Plaats in het table een of meerdere rijen met `<tr>` (table-row).
#
#
# - Zet in elk rij zo veel cellen als je wilt met het `<td>`-element (table data), of, als deze een kolom-kop is met het `<th>`-element (tabel header). Let op: `<th>` gebruik je dus alleen voor de bovenste rij.
#
# - Uiteraard voeg je voor ieder element ook een sluit-tag toe, dus `</td>`, `</tr>` en `</table>`.
#
# - Zorg ervoor dat je code netjes is uitgelijnd (met <b>TAB</b>). Zo maak je minder snel fouten.
#
# <b>Voorbeeld:</b><br>
#
#
# <table><tr bgcolor="#F5CBA7" align="left"><th>HTML-code:</th><th>In de browser:</th></tr>
#         <tr bgcolor="#FEF9E7" valign="top">
# <td>
#
# ```
# <table>
#     <tr>
#             <th>Kolom 1:</th>
#             <th>Kolom 2:</th>
#     </tr>
#     <tr>
#             <td>aardappel</td>
#             <td>bosbes</td>
#     </tr>
#     <tr>
#             <td>appel</td>
#             <td>banaan</td>
#     </tr>
#     <tr>
#             <td>aardbei</td>
#             <td>braam</td>
#     </tr>
# </table>
#
# ```
# </td>
#
# <td><img src="img/1_13_voorbeeldTabel.png" border="1" alt="Voorbeeld tabel">
# </td></tr>
# </table>
#
#
# Hoe je de kleur en stijl van randen precies kunt aanpassen, leer je in paragraaf <a href="Architectuur_H2.ipynb#H2.7">2.7: Opmaak van tabellen</a>.
# </td></tr></table>

# %% [markdown]
# <hr>
#
# # <span style="color:brown">1.14: Speciale tekens</span>
#
# <table><tr><td>
#
# ## <span style="color:brown">Unicode karakterset</span>
#
# In periode 1 hebben we geleerd over Unicode, en over hoe we tekens en karakters zoals smileys binair konden opschrijven. Zo hoort bij deze emoji: <br>
#
#
# &ensp;&ensp;<img src="img/emoji.png" border="1" alt="Emoji">
#
# de volgende binaire codering: 01010101 00101011 00110001 01000110 00110110 00110000 00110110
#
#
#
# Alles op je website wordt ook in nullen en enen omgezet. Het gebruikt hiervoor de uncode codering. Dat staat in de header van je bestand aangegeven met utf-8:<br>
#
#
# &ensp;&ensp;<img src="img/utf-8.png" border="1" alt="UTF-8 aangeven in HTML-code">
#
#
# Wil je een speciale teken gebruiken in je site, iets wat niet op je toetsenbord voorkomt, dan kun je de HTML de utf-8 codering gebruiken. Je gebruikt dan de decimale waarde van de codering in je HTML, voorafgaand met een `&#` en afgesloten met een `;`.
# Sommige tekens komen vaak voor en hebben een iets leesbaardere code.
#
# <b>Voorbeeld:</b>
#
# Karakter: é
#
# Decimale codering: 233
#
# HTML-code:  `&#233;` (decimaal) of `&eacute`;
#
#
# Dus het woord '<i>één</i>' krijg je met de code `&#233;&#233;n` of  `&eacute;&eacute;n`.
#
# Hier zijn nog wat voorbeelden:
#
# &ensp;&ensp;<img src="img/1.14_specialeTekens.png" border="1" alt="Codering voor speciale tekens">
#
#
#
# Op internet kun je de HTML-codes voor allerlei speciale tekens vinden, bijvoorbeeld:
#
# - <a href="https://www.w3schools.com/charsets/ref_utf_latin1_supplement.asp">letters met accenten
#
# - <a href="https://www.w3schools.com/charsets/ref_utf_symbols.asp">verschillende icoontjes</a>
#
#
# - <a href="https://www.w3schools.com/charsets/ref_utf_math.asp">wiskunde tekens</a>
#
# Aan de linkerkant van deze pagina's kun je nog meer speciale tekens vinden.
#
# </td></tr></table>

# %% [markdown]
# <hr>
#
# # <span style="color:brown">1.15: Samenvatting</span>
#
# <table><tr bgcolor="#FEF9E7"><td>
# Inhoud van hoofdstuk:
#
# - Een HTML-pagina sla je altijd op met de extensie .html
#
# - De hoofdpagina van een website is index.html
#
# - Een HTML-pagina bestaat altijd uit een `<head>` en een `<body>`
#
# - Een tag staat altijd tussen `<` en `>`. Bijvoorbeeld: `<b>`
#
# - Bij een tag hoort (vrijwel altijd) een afsluitende tag, herkenbaar aan de `/`. Bijvoorbeeld: `</b>`
#
#
# - Wanneer begin- en eindtag op meerdere regels staan zorg je ervoor dat de code daartussenin ingesprongen wordt.
#
# - Met commentaar tags `<!-- commentaar -->` kun je HTML-code toelichten
#
#
# Je weet nu:
# - wat een element, een starttag, een eindtag, een attribuut en een attribuutwaarde is;
#
# - hoe je een HTML-pagina aan kunt maken, opslaan, wijzigen;
#
# - hoe je een HTML-pagina kunt bekijken in jouw browser;
#
# - hoe je koppen (`<h1>`, `<h2>`), alinea's (`<p>`), (on)genummerde lijsten (`<ul>`, `<ol>`) en tabellen (`<table>`, met `<tr>` en `<td>`) kunt maken in HTML;
#
# - hoe je links (`<a href="..">..</a>`) kunt maken en afbeeldingen (`<img scr="">`) kunt tonen;
#
# - hoe je commentaar (`<!-- .. -->`) aan je HTML-code kunt toevoegen;
#
# - hoe je code netjes uitgelijnd houdt;
#
# - hoe je versiebeheer in Visual Studio Code gebruikt.
#
# </td></tr></table>
