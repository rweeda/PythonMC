# %% [markdown]
# <table><tr><td>
# Ter afsluiting van deze module maak je een aantal taken, waaronder je eigen website.
# Dit telt mee voor je <b>PTA</b>.
# Let op: Je moet voor deze praktische opdracht meerdere taken inleveren!
#
# ### <span style="color:green">Wat inleveren:</span>
# Kijk goed bij de taak omschrijvingen en de beoordeling (zie hieronder) wat van je verwacht wordt!
# 1) PO TAAK 1: USABILITY: Kort usability evaluatie van een ander website.
# 2) PO TAAK 2: WEBSITE ONTWERP: (Foto) van schermlayout + overzicht opmaakstijlen
# 3) PO TAAK 3: SECURITY: (a) Opdracht Kwetsbaarheden en (b) Opdracht Digitale wetgeving
# 4) PO TAAK 4: WEBSERVICES: Een link naar je code in VSC met live Buienradar gegevens.
# 5) PO TAAK 5: EIGEN WEBSITE: Een link naar je code in VSC.
#
# ### <span style="color:green">Hoe inleveren:</span>
# Lever individueel 1 Word bestand  in via <b>Teams Opdrachten</b> in met daarin jouw naam, naam van je partner, de opdrachten (PO TAAK 1, PO TAAK 2, TAAK 3) en links naar je code (PO TAAK 4, PO TAAK 5). Als je bij TAAK 3 of TAAK 4 in tweetallen hebt gewerkt: geef de naam van je partner, 1 persoon levert de opdracht in.
#
# ### <span style="color:green">Wanneer inleveren:</span>
# De deadline staat op de planner.
# Elk 24 uur te laat kost je 0,5 punt aftrek op je uiteindelijk cijfer.
#
# ### <span style="color:green">Beoordeling:</span>
# Je wordt beoordeeld op de kwaliteit van je werk/code, en de manier waarop je gewerkt hebt, en dus niet alleen op wat het doet. Zie de beoordelingscriteria <a href="img/BeoordelingsRubrics.xlsx">hier</a>, of onderaan deze pagina.
#
#
#
#
# </td></tr></table>

# %% [markdown]
# <table bgcolor="#EAFAF1"><tr><td>
#
# ### <span id="PO1" style="color:green"> PO TAAK 1: USABILITY</span>
#
# <b>LET OP: BELANGRIJKE OPDRACHT, DIT IS ONDERDEEL VAN JE PO EN TELT DUS MEE VOOR JE PTA-CIJFER.</b>
#
# Je mag deze opdracht in tweetallen doen.
#
# Beantwoord de onderstaande vragen in een (Word)document over een website van je keuze.
#
# b) Omschrijf 2 heuristieken van Nielsson (zie hoofdstuk <a href="Architectuur_H3.ipynb#H3.1">3.1: Ontwerp vuistregels</a>) waar de website aan voldoet. Leg uit waarom je dat vind. Gebruik screenshots om je voorbeelden toe te lichten. Tip: in Windows maak je makkelijk een screenshot van een deel van je scherm met WINDOWS+SHIFT+S.
#
# c) Geef voorbeelden van 2 heuristieken van Nielsson waar de website niet (helemaal) aan voldoet. Leg uit. Gebruik screenshots om je voorbeelden toe te lichten.
#
# d) Geef bij ieder voorbeeld uit (c) een verbetervoorstel. Leg uit waarom dat beter is.
#
# e) Lever dit in bij je eindopdracht.
#
# </td></tr></table>

# %% [markdown]
# <table bgcolor="#EAFAF1"><tr><td>
#
# ### <span id="PO2" style="color:green">PO TAAK 2: WEBSITE ONTWERPEN</span>
#
# <b>LET OP: BELANGRIJKE OPDRACHT, DIT IS ONDERDEEL VAN JE PO EN TELT DUS MEE VOOR JE PTA-CIJFER.</b>
#
# Deze opdracht maak je <b>individueel</b>.
#
# Als onderdeel van je PO moet je je eigen website ontwerpen en daarna bouwen. Je laat daarmee zien wat je tot nu toe geleerd hebt.
#
# Waar je website over gaat mag je helemaal zelf kiezen!
#
# Voordat je begint met het programmeren van je site maak je van je hoofdpagina een ontwerp. De opdracht is nu dus om een ontwerp van je site te maken:
#
# a) Lees eerst '<i>PO taak 5: Eigen Website</i>' zodat je weet wat je uiteindelijk moet maken.
# (kortom, jouw website moet bestaan uit 1 hoofdpagina en minstens 3 andere pagina's).
#
# b) Kies een onderwerp voor je eigen website.
#
# d) Teken een ontwerp voor je hoofdpagina zoals je geleerd hebt bij <a href="Architectuur_H3.ipynb#H3.3">3.3: Ontwerp maken</a>:
#
# -  een layout (in Powerpoint of op papier met potlood- maak er dan een foto van) van je hoofdpagina of subpagina's (zoals hieronder links is afgebeeld);
#
# - de opmaakstijlen (zoals hieronder rechts is afgebeeld) dat voor alle pagina's geldt.
#
# e) Lever (een foto van) dit in bij je eindopdracht.
#
# Hieronder is een voorbeeld van wat er van je verwacht wordt:
#
#
#
# <table>
#     <tr>
#     <th>Layout:</th><th>Opmaak:</th>
#     </tr>
#     <tr>
#     <td><img src="img/3.3_layout_voorbeeld.png" border="1" alt="Voorbeeld van een pagina layout" width="350"></td>
#     <td><img src="img/3.3_opmaak_voorbeeld.png" border="1" alt="Voorbeeld van een opmaakstijlen" width="350"></td>
#     </tr>
# </table>
#
#
#
# </td></tr></table>

# %% [markdown]
# <table bgcolor="#EAFAF1"><tr><td>
#
#
# ### <span id="PO3" style="color:green">PO TAAK 3: Security</span>
#
# <b>LET OP: BELANGRIJKE OPDRACHT, DIT IS ONDERDEEL VAN JE PO EN TELT DUS MEE VOOR JE PTA-CIJFER.</b>
#
# Je mag deze opdracht in tweetallen doen.
#
# Voor het Security onderdeel van je PO moet je 2 opdrachten maken:
# 1) <a href="Architectuur_H5.ipynb#PO3A">PO TAAK 3A: SECURITY KWETSBAARHEDEN (DEEL 1)</a>
# 2) <a href="Architectuur_H5.ipynb#PO3B">PO TAAK 3B: DIGITALE WETGEVING (DEEL 2)</a>
#
# </td></tr></table>

# %% [markdown]
# <table bgcolor="#EAFAF1"><tr><td>
#
#
# ### <span id="PO4" style="color:green">PO TAAK 4: WEBSERVICES (Buienradar)</span>
#
# <b>LET OP: BELANGRIJKE OPDRACHT, DIT IS ONDERDEEL VAN JE PO EN TELT DUS MEE VOOR JE PTA-CIJFER.</b>
#
# Je mag deze opdracht in tweetallen doen.
#
# <b>Opdracht:</b> Maak een webpagina die gebruik maakt van de live weergegevens van Buienradar van een andere locatie dan Arnhem. Daarin moet ten minste tenmiste komen:
# - 3 soorten informatie over het weer dat je met behulp van de json bestand inlaad
# - 1 widget
# - Bronvermelding
# Laat op de site zien wat die gegevens betekenen: je laat natuurlijk niet alleen een getal zien, maar geeft aan dat het biivoorbeeld toe de windsnelheid in Assen is.
#
# <b>Gegeven code:</b> Gebruik de gegeven code in de map 'PO_TAAK4_WEBSERVICES' als uitgangspunt en pas die aan:
# - <a href="PO_TAAK4_WEBSERVICES/index.html">index.html</a>
# - <a href="PO_TAAK4_WEBSERVICES/script.js">script.js</a>
#
# <b>Uitleg:</b> Uitleg, inclusief een filmpje, staat in <a href="Architectuur_H6.ipynb">Architectuur_H6</a>.
#
# <b>Inleveren:</b> Lever je code in bij je eindopdracht.
# Als je in tweetallen werkt: 1 persoon levert de link in, geef de naam van je partner in je verslag.
#
#
# </td></tr></table>

# %% [markdown]
# <table bgcolor="#EAFAF1"><tr><td>
#
#
# ### <span id="PO5A" style="color:green"> PO TAAK 5A: FRAME VAN WEBSITE BOUWEN (DEEL 1)</span>
#
#
#
# <b>LET OP: BELANGRIJKE OPDRACHT, DIT IS ONDERDEEL VAN JE PO EN TELT DUS MEE VOOR JE PTA-CIJFER.</b>
#
# Deze opdracht is individueel.
#
# Als het goed is heb je <a href="Architectuur_PO.ipynb#PO2"><i>PO TAAK 2. WEBSITE ONTWERPEN</i></a> af. Zo niet, maak die dan eerst, want die heb je nodig. In deze opdracht ga je jouw ontwerp voor je website omzetten in code. Je gaat dus beginnen aan het bouwen van je eigen website:
#
# a) Pak je ontwerp uit <a href="Architectuur_PO.ipynb#PO2"><i>PO TAAK 2. WEBSITE ONTWERPEN</i></a>.
#
# b) Maak voor je bestanden een map aan met de naam '<i>Mijn_website</i>'. Maak twee bestanden aan binnen die map, namelijk: <i>index.html</i> en <i>style.css</i>.
#
#
# c) Zet je ontwerp om in code. Doe dit stap-voor-stap, net als in paragraaf <a href="Architectuur_H4.ipynb#H4.4">4.4: Blokken op de juiste plaats</a> is voorgedaan.
#
#
# d) Zodra je een deel werkend hebt, maak je gebruik van versiebeheer, zoals in paragraaf <a href="Architectuur_H1.ipynb#H1.9">1.9 Versiebeheer</a></span> is uitgelegd. Geef je commit een zinvolle label, bijvoorbeeld '<i>frame af & getest</i>'.
#
# </td></tr></table>

# %% [markdown]
# <table bgcolor="#EAFAF1"><tr><td>
#
# ### <span id="PO5B" style="color:green">PO TAAK 5B: WEBSITE AFBOUWEN (DEEL 2)</span>
#
# <b>LET OP: BELANGRIJKE OPDRACHT, DIT IS ONDERDEEL VAN JE PO EN TELT DUS MEE VOOR JE PTA-CIJFER.</b>
#
# Deze opdracht maak je <b>individueel</b>.
#
#
# <hr>
#
# ### <span style="color:green">Uitleg Eigen website:</span>
#
# Maak een website bestaande uit meerdere pagina's waarin je laat zien wat je geleerd hebt. Maak de website door zelf de code in HTML en CSS te schrijven.  Alles wat behandeld wordt tijdens de les en in het lesmateriaal staat is onderdeel van de stof. De opgaven die in het lesmateriaal staan kun je zelf gebruiken als oefening, die hoef je niet in te leveren.
#
# Hieronder staan de vereisten van de website, aanwijzingen van hoe je te werk kan gaan, de beoordeling, en uitbreidingen waarmee je een hoger cijfer kan krijgen.
#
# <table><tr bgcolor="#FEF9E7"><td>
# <b>Lees onderstaand goed door voordat je begint!</b>
# </td></tr></table>
#
#
#
#
# <hr>
#
# ### <span style="color:green">Vereisten voor de website:</span>
#
# - De website bestaat uit minstens 4 pagina's.
# - De website heeft één hoofdpagina: index.html
# - De website heeft precies <b>één</b> stylesheet: style.css.
# - Elke pagina heeft een menu waarmee je kunt doorklikken naar alle andere pagina's.
# - Je moet minstens één geordende lijst (`<ol>`) en één ongeordende lijst (`<ul>`) hebben (bijvoorbeeld een profielpagina met je hobby’s, of je favoriete vakantiebestemmingen).
#
# - Een fotopagina met minimaal 4 foto's in een tabel waarbij elke foto klikbaar is en dus verwijst naar een andere website of pagina (bijvoorbeeld: als je foto is gemaakt in Spanje klikt, gaat deze naar de wikipedia van Spanje). Minimaal 1 externe link (naar een andere website). Denk ook aan wat er getoond wordt als je foto niet kan laden. Probeer aan te sluiten bij het onderwerp van je website.
#
# - Je HTML en CSS code is netjes gestructureerd en voorzien van commentaar.
# - Je project bevat geen code dat niet gebruikt wordt (denk er aan om je CSS op te ruimen, gooi ook alle ongebruikte bestanden weg).
# - Versiebeheer: Maak structureel gebruik van versiebeheer met zinvolle labels (bv. heb je de frame van je ontwerp juist in code omgezet, doe dan een commit met de tekst "frame af & getest")
#
# <hr>
#
#
#
# ### <span style="color:green">Hoe te beginnen:</span>
#
# Als het goed is heb je <a href="#PO5A">PO TAAK 5A: FRAME VAN WEBSITE BOUWEN (DEEL 1)</a> af. Zo niet, maak die dan eerst, want die heb je nodig.
#
#
#
# a) Ga naar de map met je werk voor <a href="#PO5A">PO TAAK 5A: FRAME VAN WEBSITE BOUWEN (DEEL 1)</a>, waar je index.html en je style.css staat.
#
# b) Maak binnen de map die je inje website 3 nieuwe lege HTML-pagina's aan. Geef ze zinvolle namen, gebruik hiervoor de namen dat je bij <a href="#PO2"><i>PO TAAK 2. WEBSITE ONTWERPEN</i></a> had bedacht.
#
#
# c) Voeg een menu toe aan je hoofdpagina, net als in paragraaf <a href="Architectuur_H4.ipynb#H4.5">4.5 Menubalk</a> is uitgelegd.
#
# d) Test je menu door op elke link te drukken.
#
# e) Zodra je een deel werkend hebt, maak je gebruik van versiebeheer, zoals in paragraaf <a href="Architectuur_H1.ipynb#H1.9">Versiebeheer</a> is uitgelegd. Geef je commit een zinvolle label, bijvoorbeeld '<i>frame af & getest</i>')
#
#
# f) Kopieer de code van je hoofdpagina naar de andere pagina's. Pas voor elke pagina de tekst en de menu aan. Test alle links. Maak gebruik van versiebeheer.
#
#
#
#
# <hr>
#
#
#
# ### <span style="color:green">Uitbreidingen:</span>
# Hoe meer je laat zien wat je geleerd hebt, hoe hoger je cijfer. Haal dus al je kennis uit de kast!
# Ga naast de aangeboden stof ook zelf op zoek gaan naar verdieping. Op internet heel veel informatie te vinden. Probeer nieuwe dingen uit! Maak fouten en leer daarvan, zo leer je beter hoe het echt in elkaar zit (en als je daarover reflecteerd krijg je nog een hoger cijfer ook!).<br>
# Let er wel op dat je niet zomaar dingen moet knippen en plakken zonder dat je begrijpt wat het doet. Als je het niet helemaal begrijpt, moet je het niet gebruiken! Leen je iets, maak dan gebruik van bronvermelding en geef in commentaar aan wat het doet en hoe het werkt. Alle code die in je website voorkomt moet je kunnen uitleggen.
# <hr>
#
#
#
#
# </td></tr></table>

# %% [markdown]
# <table><tr><td>
#
# ### <span style="color:green">Beoordeling:</span>
# <a href="img/BeoordelingsRubrics.xlsx">Hier</a> zie je hoe je beoordeeld wordt.
#
# <img src="img/BeoordelingsRubrics.png" alt="Beoordelingsrubrics voor PTA">
# </td></tr></table>
